# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("/home/alexg/Bedu/Project/Dataframe/ks_df_modified_python2.csv")
df.count()
# Out:
# ID                  374853
# name                374853
# category            374853
# main_category       374853
# currency            374853
# deadline            374853
# goal                374853
# launched            374853
# pledged             374853
# state               374853
# backers             374853
# country             374853
# usd pledged         374853
# usd_pledged_real    374853
# usd_goal_real       374853
# dtype: int64

# %%
include =['object', 'float']
desc=df.describe(include = include)
desc
# Out:
#                             name        category main_category currency  \
# count                     374853          374853        374853   374853
# unique                    372061             159            15       14
# top     New EP/Music Development  Product Design  Film & Video      USD
# freq                          13           22310         62694   292618
# mean                         NaN             NaN           NaN      NaN
# std                          NaN             NaN           NaN      NaN
# min                          NaN             NaN           NaN      NaN
# 25%                          NaN             NaN           NaN      NaN
# 50%                          NaN             NaN           NaN      NaN
# 75%                          NaN             NaN           NaN      NaN
# max                          NaN             NaN           NaN      NaN
#
#           deadline          goal             launched       pledged   state  \
# ...
