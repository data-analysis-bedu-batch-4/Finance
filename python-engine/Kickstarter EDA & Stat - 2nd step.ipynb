# %% [markdown]
# # Exploratory Data Analysis - 2nd Step
#
#     Second section of the data mining.
#     For this purpose, the intention is dropping the values of dates that are generating outliers since the date stamp is incorrect

# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("/home/alexg/Bedu/Project/Dataframe/ks_df_modified_python1.csv")
df.count()
# Out:
# ID                  374860
# name                374860
# category            374860
# main_category       374860
# currency            374860
# deadline            374860
# goal                374860
# launched            374860
# pledged             374860
# state               374860
# backers             374860
# country             374860
# usd pledged         374860
# usd_pledged_real    374860
# usd_goal_real       374860
# dtype: int64

# %%
Specdate = df[df.launched != '1970-01-01 01:00:00']
df[df.launched != '1970-01-01 01:00:00']
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 374855   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 374856   999977640                                          The Tribe
# 374857   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 374858   999987933                           BioDefense Education Kit
# 374859   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %%
Specdate.to_csv('/home/alexg/Bedu/Project/Dataframe/ks_df_modified_python2.csv', index = False)

# %%
Specdate.count()
# Out:
# ID                  374853
# name                374853
# category            374853
# main_category       374853
# currency            374853
# deadline            374853
# goal                374853
# launched            374853
# pledged             374853
# state               374853
# backers             374853
# country             374853
# usd pledged         374853
# usd_pledged_real    374853
# usd_goal_real       374853
# dtype: int64
